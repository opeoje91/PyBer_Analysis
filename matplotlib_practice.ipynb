# %%
#Import dependencies.
import matplotlib.pyplot as plt

# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# Create the plot
plt.plot(x_axis, y_axis)
plt.show()

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_axis, y_axis)

# %%
# Create the plot.
plt.plot(x_axis, y_axis, marker="*", color="blue", linewidth=2, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add a grid.
plt.grid()
# Add the legend.
plt.legend()

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)
ax.plot(x_axis, y_axis, marker="D", color="green", linewidth=2, label='Boston')

# Create labels for the x and y axes.
ax.set_xlabel("Date")
ax.set_ylabel("Fare($)")

# Set the y limit between 0 and 45.
ax.set_ylim(0, 45)

# Create a title.
ax.set_title("PyBer Fare by Month")

# Add a grid.
ax.grid()

# Add the legend.
ax.legend("Boston")

# %%
# Create the plot
plt.bar(x_axis, y_axis, color="green", label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Create the plot horizontal bar
plt.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
#Create the plot by switching cells
plt.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot use gca:get curtrnt axis
plt.barh(x_axis, y_axis)
plt.gca().invert_yaxis()

# %%
# Create the plot, Change the bar colors to magenta, 
plt.barh(x_axis, y_axis, color = "magenta", label = "Boston")


#Invert the y-axis so that January is at the top
plt.gca().invert_yaxis()

# Add a legend
plt.legend()

#Add a title and axes labels.
plt.xlabel("Fares($)")
plt.ylabel("Date")
plt.title("PyBer Fare by Month")
# Out:
# Text(0.5, 1.0, 'PyBer Fare by Month')

# %%
# Create plot with  ax.plt()
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis, color="black", label='New York')
# Out:
# <BarContainer object of 12 artists>

# %%
# create plot using object orieted matplotlib
fig, ax = plt.subplots()
#ax.barh(x_axis, y_axis)
ax.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# create plot using object orieted matplotlib
fig, ax = plt.subplots()

#Switch the axis so that the Fare($) data is on the x-axis, Change the bar color to cyan,
ax.barh(x_axis, y_axis, color = "cyan")

#Invert the y-axis data.
ax.invert_yaxis()

#Add a legend for the city of Chicago.
ax.legend("Chicago")

#Add a title and axes labels.
ax.set_xlabel("Date")
ax.set_ylabel("Fares($)")
ax.set_title("PyBer Fare by Month")
# Out:
# Text(0.5, 1.0, 'PyBer Fare by Month')

# %%
plt.plot(x_axis, y_axis, 'o')

# %%
#Create plot and Change the color of the markers to red, Add a legend for the city of Chicago.
#plt.scatter(x_axis, y_axis, c = "red", label = "Chicago")

# Switch the axis so that the Fare($) data is on the x-axis.
plt.scatter(y_axis, x_axis,c = "red", label = "Chicago" )

#Invert the y-axis so that January is at the top.
plt.gca().invert_yaxis()

#Add a title and axes labels.
plt.ylabel("Date")
plt.xlabel("Fares($)")
plt.title("PyBer Fare by Month")

#Add a legend for the city of Chicago.
plt.legend()

#Add a limit for the x-axis data.
plt.xlim(0, 45)
# Out:
# (0.0, 45.0)

# %%
plt.scatter(x_axis, y_axis, s=y_axis_larger)
y_axis_larger = []
for data in y_axis:
    y_axis_larger.append(data*3)

# %%
plt.scatter(x_axis, y_axis, s = [i * 3 for i in y_axis])

# %%
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis)

# %%
#create scatter using object oriented matplotlib
fig, ax = plt.subplots()
# create ax plot, Change the color of the markers to sky blue, Change the size of the markers to 5 times each data point.
#Add a black edge color to the circles.Make the linewidth of the circles 2 points.
ax.scatter(y_axis, x_axis, s=[i*5 for i in y_axis], c = "skyblue", edgecolor = "black", linewidth = 2,)

#Switch the axis so that the Fare($) data is on the x-axis.Invert the y-axis so that January is at the top.
ax.invert_yaxis()

#Add a legend for the city of Boston.
ax.legend("Boston")

#Add a title.
ax.set_ylabel("Date")
ax.set_xlabel("Fares($)")
ax.set_title("PyBer Fare by Month")

#Add a limit for the x-axis data.
ax.set_xlim(0, 45)



#Make the color 20% transparent.
# Out:
# (0.0, 45.0)

# %%
plt.subplots(figsize=(8, 8))
plt.pie(y_axis, labels=x_axis)
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%')
plt.show()

# %%
# Assign 12 colors, one for each month.
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.subplots(figsize=(8, 8))
plt.pie(y_axis,
    explode=explode_values,
    colors=colors,
    labels=x_axis,
    autopct='%.1f%%')

plt.show()

# %%
#Increase the figure size to 8x8.

#define colours
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
#Explode the two highest percentage months.
explode_values = (0, 0, 0.2, 0, 0.0, 0, 0.2, 0, 0, 0, 0, 0)
fig, ax = plt.subplots(figsize=(8, 8))
#Add a percentage to one decimal place to each wedge of the pie.
ax.pie(y_axis,labels=x_axis, autopct='%.1f%%', shadow = True, startangle = 90, counterclock = False, colors = colors, explode = explode_values)
plt.show()
# Add a shadow.

# Add a start angle so that January is at the top.

# Reverse the order so that the month order is in a clockwise direction.

# Add new colors of your own choosing or use the colors from the previous pie chart.
